# %%
cd /content/drive/My Drive/Machine Learning With Python/Clustering/Kmeans Clustering
# Out:
# /content/drive/My Drive/Machine Learning With Python/Clustering/Kmeans Clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from sklearn.cluster import KMeans

# %%
img=cv2.imread('image color1.jpg')

# %%
plt.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img=img.reshape((img.shape[1]*img.shape[0],3))

# %%
md=[]

# %%
for i in range(1,21):
  kmeans=KMeans(n_clusters=i)
  kmeans.fit(img)
  o=kmeans.inertia_
  print(o)
  md.append(o)
# Out:
# 2672238875.827385
# 1085052556.3480175
# 745289730.4436793
# 548035555.9043794
# 432110192.62334543
# 347697363.5670138
# 301778015.05159706
# 268990129.78560364
# 242278768.04862922
# 218316212.7823484
# 200009981.70677444
# 185876979.33540443
# 174619561.54477546
# 162374628.52185062
# 151732130.30764008
# 142652095.6106111
# 136091928.78750035
# 130115061.19536003
# 123581091.73044069
# 118135027.35661972

# %%
md
# Out:
# [2672238875.827385,
#  1085052556.3480175,
#  745289730.4436793,
#  548035555.9043794,
#  432110192.62334543,
#  347697363.5670138,
#  301778015.05159706,
#  268990129.78560364,
#  242278768.04862922,
#  218316212.7823484,
#  200009981.70677444,
#  185876979.33540443,
#  174619561.54477546,
#  162374628.52185062,
#  151732130.30764008,
#  142652095.6106111,
#  136091928.78750035,
#  130115061.19536003,
#  123581091.73044069,
#  118135027.35661972]

# %%
len(md)
# Out:
# 20

# %%
plt.plot(x,md)
plt.show()

# %%
kmeans=KMeans(n_clusters=5)

# %%
s=kmeans.fit(img)

# %%
s
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels=kmeans.labels_

# %%
labels
# Out:
# array([3, 3, 3, ..., 1, 1, 1], dtype=int32)

# %%
centroid=kmeans.cluster_centers_

# %%
centroid
# Out:
# array([[184.97085783, 147.58582176,  29.5372686 ],
#        [ 40.53175328,  54.64174853,   9.56666545],
#        [173.3732169 , 136.11690746, 113.33533742],
#        [ 97.81588738,  91.09586548,  63.96108686],
#        [240.22273291, 204.74771599, 142.3548951 ]])

# %%
labels=list(labels)

# %%
percent=[]
for i in range(len(centroid)):
  j=labels.count(i)
  j=j/(len(labels))
  percent.append(j)

# %%
percent
# Out:
# [0.16569648692810457,
#  0.23214954384531591,
#  0.18641493055555555,
#  0.26451865468409586,
#  0.1512203839869281]

# %%
plt.pie(percent,colors=np.array(centroid/255),labels=np.arange(len(centroid)))
plt.show()
